# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent.joinpath('src')))
from verify_route import verify_cta_route
from verify_route import verify_pace_route
from verify_route import verify_metra_route

# %%
aprx = arcpy.mp.ArcGISProject('CURRENT')
map = aprx.listMaps()[0]
map.openView()

# %%
verify_cta_route('192', 165)
# Out:
# (96.3855421686747, 0.6762985966192887)

# %%
# verify_pace_route('410-377', 165)

# %%
# verify_metra_route('SWS', 165)
